# %% [markdown]
# # ステップ18: データ分析チャレンジ
#
# **ランク：イノベーター（2/2） → クリアでマスターにランクアップ！**
#
# 今回学ぶこと：問題設定 / 実験設計 / 分析・結論
#
# 自分で「問い」を決めて、データ収集→分析→結論のサイクルを自力で回そう！

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## 実験計画
#
# まずここに計画を書こう！（このセルをダブルクリックして編集してね）
#
# ### 問い
# （何を知りたいか）
#
# ### 予想
# （結果はどうなると思うか）
#
# ### データ収集方法
# （どうやってデータを集めるか）
#
# ### 分析方法
# （集めたデータをどう処理するか）

# %% [markdown]
# ## プログラミング開始！

# %%
# データ収集
# ここにデータを集めるコードを書こう

# %%
# 分析・可視化
# ここにデータを分析してグラフを作るコードを書こう
# import matplotlib.pyplot as plt や import pandas as pd を使おう

# %% [markdown]
# ## 結論
#
# （このセルをダブルクリックして結論を書こう）
#
# ### わかったこと
#
# ### 予想との比較
#
# ### 感想

# %%
player.logout()
