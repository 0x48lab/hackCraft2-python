# %% [markdown]
# # ステップ19: AIペットを作ろう
#
# **ランク：マスター（1/2）**
#
# 今回学ぶこと：API Key / リクエスト・レスポンス / プロンプト設計

# %%
# !pip install py2hackCraft2 google-generativeai -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks
import google.generativeai as genai

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %%
# ===== Gemini API の設定 =====
# API Keyは講師から配布されたものを入れてね
genai.configure(api_key="ここにAPIキーを入れる")
model = genai.GenerativeModel("gemini-2.0-flash")
print("Gemini API 準備完了！")

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: AIに質問してみよう
# model.generate_content("質問内容") でAIに質問しよう
# 3つ以上の質問をして、AIが間違った回答をした例を見つけよう

# %%
# ミッション2: AIチャットボットペット
# entity.wait_for_player_chat() でプレイヤーの入力を受け取ろう
# プロンプト設計でペットのキャラクターを設定しよう
# while True で会話ループを作り、「終わり」で終了するようにしよう

# %%
player.logout()
