# %% [markdown]
# # ステップ10: 釣りの確率実験
#
# **ランク：リサーチャー（2/2） → クリアでプログラマーにランクアップ！**
#
# 今回学ぶこと：イベントログ / watch_events / 確率計算

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks
from IPython.display import clear_output

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: 釣りデータ収集 + リアルタイムグラフ
# watch_events() でリアルタイム監視しよう
# callbackでグラフを更新しよう（clear_output + plt.show）
# import matplotlib.pyplot as plt と import pandas as pd を使おう

# %%
# ミッション2: 確率計算レポート
# pandasで確率を計算しよう
# 円グラフで確率分布を表示しよう
# テキストセルに考察を書こう

# %%
player.logout()
