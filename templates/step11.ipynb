# %% [markdown]
# # ステップ11: 文字列と看板マスター
#
# **ランク：プログラマー（1/2）**
#
# 今回学ぶこと：split・join / replace / write_sign・read_sign

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: 看板伝言板
# 3枚以上の看板にメッセージを書き込もう
# 全看板を読み取ってリストに格納し、joinで1つにまとめて表示しよう
# API: entity.write_sign(), entity.read_sign()

# %%
# ミッション2: 看板ネットワーク情報システム
# 看板からデータをread_signで読み取ろう
# splitでデータを分割して加工しよう
# replaceで一部のデータを変更して、新しい看板にwrite_signで書き込もう

# %%
player.logout()
