# %% [markdown]
# # ステップ20: 総合プロジェクト + 発表
#
# **ランク：マスター（2/2）**
#
# 今回学ぶこと：企画・設計 / 実装 / プレゼンテーション
#
# これまで学んだ全技術を使って、自分だけのプロジェクトを完成させよう！

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## プロジェクト企画シート
#
# （このセルをダブルクリックして編集してね）
#
# ### プロジェクト名
# （かっこいい名前をつけよう）
#
# ### 何を作る？
# （1行で説明）
#
# ### 使う技術
# （学んだことから選ぶ）
#
# ### 完成イメージ
# （最終的にどうなっていればOK？）

# %% [markdown]
# ## プログラミング開始！
#
# 必要に応じてセルを追加して、自分のプロジェクトを作ろう！

# %%
# ここにコードを書こう
# 必要なライブラリは自分でimportしよう
# 例: import random, import math, import matplotlib.pyplot as plt
# 例: import pandas as pd, from PIL import Image
# 例: import google.generativeai as genai

# %%
# 追加のコードセル

# %%
# 追加のコードセル

# %% [markdown]
# ## 発表メモ
#
# （このセルをダブルクリックして編集してね）
#
# 1. **何を作ったか**（プロジェクト名 + 一言説明）
#
# 2. **工夫したところ**（一番頑張ったポイント）
#
# 3. **感想**

# %%
player.logout()
