# %% [markdown]
# # ステップ17: ランダム建築と確率
#
# **ランク：イノベーター（1/2）**
#
# 今回学ぶこと：random.choice・randint / random.random / シード値

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks
import random

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: ランダム建築
# random.choice でブロック種類をランダムに選ぼう
# random.randint で座標をランダムに決めよう
# random.seed() を使って同じ建築を再現してみよう

# %%
# ミッション2: モンテカルロ法で円周率近似
# 正方形の中にランダムに点を打って、円の中に入った割合 × 4 = π
# import math して math.sqrt() で距離を計算しよう
# Minecraft内で可視化しよう（円の中=青、外=赤）

# %%
player.logout()
