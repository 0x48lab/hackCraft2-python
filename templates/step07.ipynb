# %% [markdown]
# # ステップ7: はじめてのデータ分析
#
# **ランク：サイエンティスト（1/2）**
#
# 今回学ぶこと：CSVファイル保存 / matplotlib / Colabのグラフ表示

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: ブロック調査 → 棒グラフ
# 周囲のブロックを調査して、Counterで集計しよう
# matplotlibで棒グラフを表示して、CSVファイルに保存しよう

# %%
# ミッション2: 円グラフ + 考察レポート
# 同じデータを円グラフにしよう
# TOP5とそれ以外を「その他」にまとめよう

# %%
player.logout()
