# %% [markdown]
# # ステップ15: ドット絵を建てよう
#
# **ランク：クリエイター（1/2）**
#
# 今回学ぶこと：PIL・Pillow / getpixel・RGB / get_block_by_color

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks
from PIL import Image

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: クリーパーの顔を建てよう
# クリーパーの顔を2次元リストで定義しよう
# 各色をget_block_by_colorでブロックに変換して配置しよう

# %%
# ミッション2: 好きな画像をMinecraftに召喚
# Image.open() で画像を読み込もう（大きい画像はresizeで縮小）
# getpixel で各ピクセルの色を取得して、get_block_by_colorでブロックに変換しよう
# 16進数カラーコード: "#{:02x}{:02x}{:02x}".format(r, g, b)

# %%
player.logout()
