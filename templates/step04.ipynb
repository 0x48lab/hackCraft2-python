# %% [markdown]
# # ステップ4: データを絞って並べよう
#
# **ランク：コレクター（2/2） → クリアでアナリストにランクアップ！**
#
# 今回学ぶこと：リスト内包表記 / sorted() / enumerate()

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: ブロック調査 + フィルタ
# entity.inspect_at() で周囲のブロックを調査しよう
# リスト内包表記で固体ブロック（airでないもの）だけをフィルタしよう

# %%
# ミッション2: ランキング報告
# 調査したブロックを出現回数順にランキングしよう
# sorted() と enumerate() を使ってランキング形式で報告しよう

# %%
player.logout()
