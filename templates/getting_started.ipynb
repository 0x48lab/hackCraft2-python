# %% [markdown]
# # hackCraft2 Python — データサイエンティストへの道
#
# PythonでMinecraftのペットをプログラミングしよう！
#
# 各ステップのリンクをクリックして始めよう。
#
# ---
#
# ## ルーキー
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 1 | Pythonで動かそう | [step01を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step01.ipynb) |
# | 2 | ループと条件分岐 | [step02を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step02.ipynb) |
#
# ## コレクター
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 3 | リストで建築 | [step03を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step03.ipynb) |
# | 4 | データを絞って並べよう | [step04を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step04.ipynb) |
#
# ## アナリスト
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 5 | 関数で部品を作ろう | [step05を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step05.ipynb) |
# | 6 | 辞書でブロック調査 | [step06を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step06.ipynb) |
#
# ## サイエンティスト
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 7 | はじめてのデータ分析 | [step07を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step07.ipynb) |
# | 8 | 自動農場を作ろう | [step08を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step08.ipynb) |
#
# ## リサーチャー
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 9 | 農場実験レポート | [step09を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step09.ipynb) |
# | 10 | 釣りの確率実験 | [step10を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step10.ipynb) |
#
# ## プログラマー
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 11 | 文字列と看板マスター | [step11を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step11.ipynb) |
# | 12 | 座標と数学 | [step12を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step12.ipynb) |
#
# ## アーキテクト
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 13 | 地形スキャン | [step13を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step13.ipynb) |
# | 14 | バイオーム判定器 | [step14を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step14.ipynb) |
#
# ## クリエイター
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 15 | ドット絵を建てよう | [step15を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step15.ipynb) |
# | 16 | 画像を加工しよう | [step16を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step16.ipynb) |
#
# ## イノベーター
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 17 | ランダム建築と確率 | [step17を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step17.ipynb) |
# | 18 | データ分析チャレンジ | [step18を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step18.ipynb) |
#
# ## マスター
#
# | # | ステップ | リンク |
# |---|---------|--------|
# | 19 | AIペットを作ろう | [step19を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step19.ipynb) |
# | 20 | 総合プロジェクト + 発表 | [step20を開く](https://colab.research.google.com/github/0x48lab/hackCraft2-python/blob/main/templates/step20.ipynb) |
