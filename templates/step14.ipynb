# %% [markdown]
# # ステップ14: バイオーム判定器
#
# **ランク：アーキテクト（2/2） → クリアでクリエイターにランクアップ！**
#
# 今回学ぶこと：特徴量設計 / スコアリング / 判定精度検証

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: 特徴量を抽出しよう
# scan_blocks で周囲のブロックを取得しよう
# 砂・草・水・石・雪のそれぞれが全体の何%を占めるか計算しよう
# from collections import Counter を使おう

# %%
# ミッション2: バイオーム判定器を作ろう
# 特徴量からバイオームを判定する predict_biome() 関数を作ろう
# entity.get_biome() で正解を取得して、判定精度を検証しよう

# %%
player.logout()
