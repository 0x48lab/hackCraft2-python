# %% [markdown]
# # ステップ9: 農場実験レポート
#
# **ランク：リサーチャー（1/2）**
#
# 今回学ぶこと：pandas（DataFrame） / describe() / groupby()

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks
import pandas as pd

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: 農場データ収集 + 分析
# 農場のデータをDataFrameに格納しよう
# describe() で統計情報を確認し、groupby() でエリア別の平均成長度を計算しよう

# %%
# ミッション2: 実験レポート完成
# 成長段階のヒストグラム、エリア別の比較グラフ、ブロック種類の分布を描画しよう
# import matplotlib.pyplot as plt を使おう

# %%
player.logout()
