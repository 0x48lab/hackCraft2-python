# %% [markdown]
# # ステップ8: 自動農場を作ろう
#
# **ランク：サイエンティスト（2/2） → クリアでリサーチャーにランクアップ！**
#
# 今回学ぶこと：複合条件分岐（and/or） / try・except / with文

# %%
# !pip install py2hackCraft2 -q

# %% [markdown]
# ## 接続設定
#
# 下のセルの `HOST`、`PORT`、`PLAYER_NAME`、`PET_NAME` を自分の設定に変更してから実行してね。

# %%
from py2hackCraft.modules import Player, LocationFactory, Volume
from py2hackCraft.material import Blocks

# ===== ここを変更してね =====
HOST = "localhost"
PORT = 25570
PLAYER_NAME = "your_name"
PET_NAME = "pet_name"
# ==========================

player = Player(PLAYER_NAME)
player.login(HOST, PORT)
entity = player.get_entity(PET_NAME)
print(f"接続OK! ペット {PET_NAME} に接続しました")

# %% [markdown]
# ## プログラミング開始！

# %%
# ミッション1: 自動農場の基本
# 5×5の範囲を耕して→植えて→肥料をやる自動農場を作ろう
# 各ステップを関数にして、try/exceptでエラーに対処しよう
# API: entity.till_at(loc), entity.plant(), entity.fertilizer_at(loc)

# %%
# ミッション2: 全自動農場 + ログ出力
# 作物の成長状態を判定して自動で収穫→再植え付けしよう
# 作業ログをCSVに保存しよう
# API: entity.harvest(), entity.inspect_down()

# %%
player.logout()
